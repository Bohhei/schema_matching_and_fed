# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("openml_15ds_attributes_nominal_matching.csv")
df.columns
# Out:
# Index(['dataset1_openml_id', 'dataset1_name', 'attr1_name',
#        'attr1_type_converted', 'dataset2_openml_id', 'dataset2_name',
#        'attr2_name', 'attr2_type_converted', 'distinct_values_cnt',
#        'distinct_values_pct', 'missing_values_pct', 'val_size_min',
#        'val_size_max', 'val_size_avg', 'val_size_std', 'val_pct_min',
#        'val_pct_max', 'val_pct_median', 'val_pct_std', 'name_dist',
#        'similarity_score', 'attributes_match'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1576 entries, 0 to 1575
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   dataset1_openml_id    1576 non-null   int64
#  1   dataset1_name         1576 non-null   object
#  2   attr1_name            1576 non-null   object
#  3   attr1_type_converted  1576 non-null   int64
#  4   dataset2_openml_id    1576 non-null   int64
#  5   dataset2_name         1576 non-null   object
#  6   attr2_name            1576 non-null   object
#  7   attr2_type_converted  1576 non-null   int64
#  8   distinct_values_cnt   1576 non-null   float64
#  9   distinct_values_pct   1576 non-null   float64
#  10  missing_values_pct    1576 non-null   float64
#  11  val_size_min          1576 non-null   float64
#  12  val_size_max          1576 non-null   float64
#  13  val_size_avg          1576 non-null   float64
#  14  val_size_std          1576 non-null   float64
# ...

# %%
df.describe()
# Out:
#        dataset1_openml_id  attr1_type_converted  dataset2_openml_id  \
# count         1576.000000           1576.000000         1576.000000
# mean            64.628807              0.248731          499.983503
# std            169.529223              0.432415          471.599454
# min             13.000000              0.000000           15.000000
# 25%             13.000000              0.000000           50.000000
# 50%             15.000000              0.000000          455.000000
# 75%             48.000000              0.000000         1092.000000
# max            969.000000              1.000000         1092.000000
#
#        attr2_type_converted  distinct_values_cnt  distinct_values_pct  \
# count           1576.000000          1576.000000          1576.000000
# mean               0.176396             0.534427             0.658818
# std                0.381278             0.303086             0.286427
# min                0.000000             0.000000             0.000000
# ...

# %%
df.nunique()
# Out:
# dataset1_openml_id       12
# dataset1_name            10
# attr1_name               43
# attr1_type_converted      2
# dataset2_openml_id       12
# dataset2_name            10
# attr2_name               43
# attr2_type_converted      2
# distinct_values_cnt      94
# distinct_values_pct     421
# missing_values_pct        7
# val_size_min             49
# val_size_max             58
# val_size_avg            240
# val_size_std            148
# val_pct_min             687
# val_pct_max             905
# val_pct_median          462
# val_pct_std             827
# name_dist               145
# similarity_score         93
# attributes_match          2
# dtype: int64

# %%
for i in df.index:
    line = df.loc[i]
    if line[0]==line[4]:
        print(line)

# %%
fig,ax = plt.subplots(1,1,figsize=(10,5))
sns.heatmap(df.corr(),ax=ax)
# Out:
# C:\Users\shepe\AppData\Local\Temp\ipykernel_22052\2770154114.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),ax=ax)
# <Axes: >
